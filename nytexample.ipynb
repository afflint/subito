# %% [markdown]
# # Low-level API example
# This example exploits the REST services provided by <a href="https://developer.nytimes.com/">NYT Developers</a>

# %%
api_key = 'YfLeAfVGZpo4lMKgj6GsSoSCTvDbepj9'

# %%
import requests

# %%
endpoint = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
parameters = {
    'q': 'politics',
    'api-key': api_key
}

# %%
response = requests.get(url=endpoint, params=parameters)

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
print(response.headers)
# Out:
# {'Date': 'Sun, 09 Jun 2019 11:11:18 GMT', 'Content-Type': 'application/json;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'nginx', 'Access-Control-Allow-Headers': 'Accept, Content-Type, Origin, X-Forwarded-For, X-Prototype-Version, X-Requested-With', 'Access-Control-Allow-Methods': 'GET, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'Content-Length, X-JSON'}

# %%
print(response.status_code)
# Out:
# 200

# %%
json_resp = response.json()

# %%
print(json_resp)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/06/01/opinion/sunday/politics-compromise-winner-take-all.html', 'snippet': 'Or at least it shouldn’t be.', 'lead_paragraph': 'Every time I left a job in government — in the Reagan administration and in both Bush administrations — my I.Q. rose by 30 points. Or so it seemed.', 'abstract': 'Or at least it shouldn’t be.', 'print_page': '3', 'blog': {}, 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/06/02/opinion/sunday/02Wehner/merlin_150248055_3aa57516-3bed-4ee2-a92d-a81b1d142ba7-articleLarge.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2019/06/02/opinion/sunday/02Wehner/merlin_150248055_3aa57516-3bed-4ee2-a92d-a81b1d142ba7-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 
# ...

# %%
print(type(json_resp))
# Out:
# <class 'dict'>

# %%
import pprint

# %%
for doc in json_resp['response']['docs']:
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(doc)
# Out:
# {   '_id': '5cf2c42e49f0eacbf1f92ede',
#     'abstract': 'Or at least it shouldn’t be.',
#     'blog': {},
#     'byline': {   'organization': None,
#                   'original': 'By Peter Wehner',
#                   'person': [   {   'firstname': 'Peter',
#                                     'lastname': 'Wehner',
#                                     'middlename': None,
#                                     'organization': '',
#                                     'qualifier': None,
#                                     'rank': 1,
#                                     'role': 'reported',
#                                     'title': None}]},
#     'document_type': 'article',
#     'headline': {   'content_kicker': None,
#                     'kicker': None,
#                     'main': 'Politics Is Not Total War',
#                     'name': None,
#                     'print_headline': 'Politics Is Not Total War',
#                     'seo': None,
# ...

# %% [markdown]
# ## Facet queries
# Use facets to view the relative importance of certain fields to a search term, and gain insight about how to best refine your queries and filter your search results.
#
# The following fields can be used as facet fields: <code>day_of_week, document_type, ingredients, news_desk, pub_month, pub_year, section_name, source, subsection_name, and type_of_material</code>.
#
# Specify facets using the facet_fields parameter. Set facet=true and the response will contain an array with a count for the five terms that have the highest count for each facet. For example, including the following in your request will add a facet array with a count for the top five days of the week to the response.

# %%
facet_query = {
    'fq': 'nba',
    'facet_fields': 'day_of_week',
    'facet': 'true',
    'begin_date': '20100101',
    'end_date': '20120101',
    'api-key': api_key
}

# %%
response = requests.get(url=endpoint, params=facet_query)

# %%
j = response.json()

# %%
j['response']['facets']
# Out:
# {'day_of_week': {'terms': [{'term': 'Thursday', 'count': 28},
#    {'term': 'Friday', 'count': 23},
#    {'term': 'Tuesday', 'count': 20},
#    {'term': 'Wednesday', 'count': 19},
#    {'term': 'Monday', 'count': 18},
#    {'term': 'Saturday', 'count': 17},
#    {'term': 'Sunday', 'count': 12}]}}

# %%
j['response']['docs'][0]
# Out:
# {'web_url': 'https://www.nytimes.com/video/movies/100000000727491/anne-buford.html',
#  'snippet': 'The director Anne Buford discusses her documentary "Elevate," about tall West African teenagers with NBA dreams.',
#  'lead_paragraph': 'The director Anne Buford discusses her documentary "Elevate," about tall West African teenagers with NBA dreams.',
#  'abstract': 'The director Anne Buford discusses her documentary "Elevate," about tall West African teenagers with NBA dreams.',
#  'blog': {},
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'wide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2011/03/15/arts/video-anne-buford/video-anne-buford-thumbWide.jpg',
#    'height': 126,
#    'width': 190,
#    'legacy': {'widewidth': 190,
#     'wideheight': 126,
#     'wide': 'images/2011/03/15/arts/video-anne-buford/video-anne-buford-thumbWide.jpg'},
#    'subType': 'wide',
#    'crop_name': 'thumbWide'},
# ...
