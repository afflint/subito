# %% [markdown]
# ## TASK: predire il numero di nuovi annunci giornalieri su subito

# %% [markdown]
# ### Data load and pre-processing

# %%
import numpy as np
import pandas as pd

# %%
data_file = 'data/classification.xlsx'
D = pd.read_excel(data_file)

# %%
D.groupby('days_from_approvation').count()
# Out:
#                        ad_id  num_images  ads_is_pro  category  \
# days_from_approvation
# 0                       2133        2133        2133      2133
# 1                       1892        1892        1892      1892
# 2                       1758        1758        1758      1758
# 3                       1744        1744        1744      1744
# 4                       1307        1300        1307      1307
# 5                       1427        1427        1427      1427
# 6                       1330        1330        1330      1330
# 7                       1332        1331        1332      1332
# 8                       1347        1346        1347      1347
# 9                       1233        1233        1233      1233
# 10                      1237        1236        1237      1237
# 11                       781         779         781       781
# 12                       834         834         834       834
# ...
